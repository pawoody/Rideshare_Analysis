# %% [markdown]
# Uber/Lyft Ride Data:
# https://www.kaggle.com/brllrb/uber-and-lyft-dataset-boston-ma

# %% [markdown]
# # Background
#
# In this project, I will compare rideshare data in Boston between Uber and Lyft From 11-26-2018 to 12-18-2018. My aim is to identify and evaluate key metrics for each company, discover trends, and identify potential areas for improvement and/or growth.
#
# Because the dataset is unannotated, extensive EDA will be necessary
#
# To/Do's (in progress):
# - Talk about Data set info
# - Background research on Uber/Lyft
# -

# %% [markdown]
# # Importing Data/EDA

# %%
# Importing libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#sns.set_palette(palette='Set2')
plt.style.use('xkcd')

# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/style/core.py in use(style)
#     110             try:
# --> 111                 rc = rc_params_from_file(style, use_default_template=False)
#     112                 _apply_style(rc)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#     986     """
# --> 987     config_from_file = _rc_params_in_file(fname, fail_on_error)
#     988
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in _rc_params_in_file(fname, fail_on_error)
#     915     rc_temp = {}
# --> 916     with _open_file_or_url(fname) as fd:
#     917         try:
#
# ~/opt/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in _open_file_or_url(fname)
#     900             encoding = "utf-8"
# --> 901         with open(fname, encoding=encoding) as f:
#     902             yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'xkcd'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-47-6f1776e041a0> in <module>
#       6
#       7 #sns.set_palette(palette='Set2')
# ----> 8 plt.style.use('xkcd')
#       9
#      10 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/style/core.py in use(style)
#     115                     "{!r} not found in the style library and input is not a "
#     116                     "valid URL or path; see `style.available` for list of "
# --> 117                     "available styles".format(style))
#     118
#     119
#
# OSError: 'xkcd' not found in the style library and input is not a valid URL or path; see `style.available` for list of available styles

# %%
# Loadiing Dataset, inspecting columns
df = pd.read_csv('rideshare_kaggle.csv')
display(df.info(), df.describe(), df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 57 columns):
# id                             693071 non-null object
# timestamp                      693071 non-null float64
# hour                           693071 non-null int64
# day                            693071 non-null int64
# month                          693071 non-null int64
# datetime                       693071 non-null object
# timezone                       693071 non-null object
# source                         693071 non-null object
# destination                    693071 non-null object
# cab_type                       693071 non-null object
# product_id                     693071 non-null object
# name                           693071 non-null object
# price                          637976 non-null float64
# distance                       693071 non-null float64
# surge_multiplier               693071 non-null float64
# latitude                       693071 non-null float64
# longitude                      693071 non-null float64
# temperature                    693071 non-null float64
# apparentTemperature            693071 non-null float64
# short_summary                  693071 non-null object
# long_summary                   693071 non-null object
# precipIntensity                693071 non-null float64
# precipProbability              693071 non-null float64
# humidity                       693071 non-null float64
# windSpeed                      693071 non-null float64
# windGust                       693071 non-null float64
# windGustTime                   693071 non-null int64
# visibility                     693071 non-null float64
# temperatureHigh                693071 non-null float64
# temperatureHighTime            693071 non-null int64
# temperatureLow                 693071 non-null float64
# temperatureLowTime             693071 non-null int64
# apparentTemperatureHigh        693071 non-null float64
# apparentTemperatureHighTime    693071 non-null int64
# apparentTemperatureLow         693071 non-null float64
# apparentTemperatureLowTime     693071 non-null int64
# icon                           693071 non-null object
# dewPoint                       693071 non-null float64
# pressure                       693071 non-null float64
# windBearing                    693071 non-null int64
# cloudCover                     693071 non-null float64
# uvIndex                        693071 non-null int64
# visibility.1                   693071 non-null float64
# ozone                          693071 non-null float64
# sunriseTime                    693071 non-null int64
# sunsetTime                     693071 non-null int64
# moonPhase                      693071 non-null float64
# precipIntensityMax             693071 non-null float64
# uvIndexTime                    693071 non-null int64
# temperatureMin                 693071 non-null float64
# temperatureMinTime             693071 non-null int64
# temperatureMax                 693071 non-null float64
# temperatureMaxTime             693071 non-null int64
# apparentTemperatureMin         693071 non-null float64
# apparentTemperatureMinTime     693071 non-null int64
# apparentTemperatureMax         693071 non-null float64
# apparentTemperatureMaxTime     693071 non-null int64
# dtypes: float64(29), int64(17), object(11)
# memory usage: 301.4+ MB
# None
#           timestamp           hour            day          month  \
# count  6.930710e+05  693071.000000  693071.000000  693071.000000
# mean   1.544046e+09      11.619137      17.794365      11.586684
# std    6.891925e+05       6.948114       9.982286       0.492429
# min    1.543204e+09       0.000000       1.000000      11.000000
# 25%    1.543444e+09       6.000000      13.000000      11.000000
# 50%    1.543737e+09      12.000000      17.000000      12.000000
# 75%    1.544828e+09      18.000000      28.000000      12.000000
# max    1.545161e+09      23.000000      30.000000      12.000000
#
#                price       distance  surge_multiplier       latitude  \
# count  637976.000000  693071.000000     693071.000000  693071.000000
# mean       16.545125       2.189430          1.013870      42.338172
# std         9.324359       1.138937          0.091641       0.047840
# min         2.500000       0.020000          1.000000      42.214800
# 25%         9.000000       1.280000          1.000000      42.350300
# 50%        13.500000       2.160000          1.000000      42.351900
# 75%        22.500000       2.920000          1.000000      42.364700
# max        97.500000       7.860000          3.000000      42.366100
#
#            longitude    temperature  ...  precipIntensityMax   uvIndexTime  \
# count  693071.000000  693071.000000  ...       693071.000000  6.930710e+05
# mean      -71.066151      39.584388  ...            0.037374  1.544044e+09
# std         0.020302       6.726084  ...            0.055214  6.912028e+05
# min       -71.105400      18.910000  ...            0.000000  1.543162e+09
# 25%       -71.081000      36.450000  ...            0.000000  1.543421e+09
# 50%       -71.063100      40.490000  ...            0.000400  1.543770e+09
# 75%       -71.054200      43.580000  ...            0.091600  1.544807e+09
# max       -71.033000      57.220000  ...            0.145900  1.545152e+09
#
#        temperatureMin  temperatureMinTime  temperatureMax  temperatureMaxTime  \
# count   693071.000000        6.930710e+05   693071.000000        6.930710e+05
# mean        33.457774        1.544042e+09       45.261313        1.544047e+09
# std          6.467224        6.901954e+05        5.645046        6.901353e+05
# min         15.630000        1.543122e+09       33.510000        1.543154e+09
# 25%         30.170000        1.543399e+09       42.570000        1.543439e+09
# 50%         34.240000        1.543727e+09       44.680000        1.543788e+09
# 75%         38.880000        1.544789e+09       46.910000        1.544814e+09
# max         43.100000        1.545192e+09       57.870000        1.545109e+09
#
#        apparentTemperatureMin  apparentTemperatureMinTime  \
# count           693071.000000                6.930710e+05
# mean                29.731002                1.544048e+09
# std                  7.110494                6.871862e+05
# min                 11.810000                1.543136e+09
# 25%                 27.760000                1.543399e+09
# 50%                 30.130000                1.543745e+09
# 75%                 35.710000                1.544789e+09
# max                 40.050000                1.545134e+09
#
#        apparentTemperatureMax  apparentTemperatureMaxTime
# count           693071.000000                6.930710e+05
# mean                41.997343                1.544048e+09
# std                  6.936841                6.910777e+05
# min                 28.950000                1.543187e+09
# 25%                 36.570000                1.543439e+09
# 50%                 40.950000                1.543788e+09
# 75%                 44.120000                1.544818e+09
# max                 57.200000                1.545109e+09
#
# [8 rows x 46 columns]
#                                      id     timestamp  hour  day  month  \
# 0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 1  4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 2  981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
# 3  c2d88af2-d278-4bfd-a8d0-29ca77cc5512  1.543554e+09     4   30     11
# 4  e0126e1f-8ca9-4f2e-82b3-50505a09db9a  1.543463e+09     3   29     11
#
#               datetime          timezone            source    destination  \
# 0  2018-12-16 09:30:07  America/New_York  Haymarket Square  North Station
# 1  2018-11-27 02:00:23  America/New_York  Haymarket Square  North Station
# 2  2018-11-28 01:00:22  America/New_York  Haymarket Square  North Station
# 3  2018-11-30 04:53:02  America/New_York  Haymarket Square  North Station
# 4  2018-11-29 03:49:20  America/New_York  Haymarket Square  North Station
#
#   cab_type  ... precipIntensityMax uvIndexTime  temperatureMin  \
# 0     Lyft  ...             0.1276  1544979600           39.89
# 1     Lyft  ...             0.1300  1543251600           40.49
# 2     Lyft  ...             0.1064  1543338000           35.36
# 3     Lyft  ...             0.0000  1543507200           34.67
# 4     Lyft  ...             0.0001  1543420800           33.10
#
#    temperatureMinTime  temperatureMax  temperatureMaxTime  \
# 0          1545012000           43.68          1544968800
# 1          1543233600           47.30          1543251600
# 2          1543377600           47.55          1543320000
# 3          1543550400           45.03          1543510800
# 4          1543402800           42.18          1543420800
#
#    apparentTemperatureMin  apparentTemperatureMinTime  apparentTemperatureMax  \
# 0                   33.73                  1545012000                   38.07
# 1                   36.20                  1543291200                   43.92
# 2                   31.04                  1543377600                   44.12
# 3                   30.30                  1543550400                   38.53
# 4                   29.11                  1543392000                   35.75
#
#   apparentTemperatureMaxTime
# 0                 1544958000
# 1                 1543251600
# 2                 1543320000
# 3                 1543510800
# 4                 1543420800
#
# [5 rows x 57 columns]

# %% [markdown]
# Inspecting dataframe columns for null/missing values:

# %%
df.isna().any()
# Out:
# id                             False
# timestamp                      False
# hour                           False
# day                            False
# month                          False
# datetime                       False
# timezone                       False
# source                         False
# destination                    False
# cab_type                       False
# product_id                     False
# name                           False
# price                           True
# distance                       False
# surge_multiplier               False
# latitude                       False
# longitude                      False
# temperature                    False
# apparentTemperature            False
# short_summary                  False
# long_summary                   False
# precipIntensity                False
# precipProbability              False
# humidity                       False
# windSpeed                      False
# windGust                       False
# windGustTime                   False
# visibility                     False
# temperatureHigh                False
# temperatureHighTime            False
# temperatureLow                 False
# temperatureLowTime             False
# apparentTemperatureHigh        False
# apparentTemperatureHighTime    False
# apparentTemperatureLow         False
# apparentTemperatureLowTime     False
# icon                           False
# dewPoint                       False
# pressure                       False
# windBearing                    False
# cloudCover                     False
# uvIndex                        False
# visibility.1                   False
# ozone                          False
# sunriseTime                    False
# sunsetTime                     False
# moonPhase                      False
# precipIntensityMax             False
# uvIndexTime                    False
# temperatureMin                 False
# temperatureMinTime             False
# temperatureMax                 False
# temperatureMaxTime             False
# apparentTemperatureMin         False
# apparentTemperatureMinTime     False
# apparentTemperatureMax         False
# apparentTemperatureMaxTime     False
# dtype: bool

# %%
na_price = df[df.price.isna() == True]
                      
print(len(na_price))
display(na_price.describe())
df.describe()
# Out:
# 55095
#           timestamp          hour           day         month  price  \
# count  5.509500e+04  55095.000000  55095.000000  55095.000000    0.0
# mean   1.544046e+09     11.626191     17.756040     11.588238    NaN
# std    6.890791e+05      6.940503      9.984649      0.492157    NaN
# min    1.543204e+09      0.000000      1.000000     11.000000    NaN
# 25%    1.543444e+09      6.000000     13.000000     11.000000    NaN
# 50%    1.543739e+09     12.000000     17.000000     12.000000    NaN
# 75%    1.544828e+09     18.000000     28.000000     12.000000    NaN
# max    1.545161e+09     23.000000     30.000000     12.000000    NaN
#
#            distance  surge_multiplier      latitude     longitude  \
# count  55095.000000           55095.0  55095.000000  55095.000000
# mean       2.191383               1.0     42.338303    -71.066230
# std        1.178985               0.0      0.047654      0.020286
# min        0.020000               1.0     42.214800    -71.105400
# 25%        1.300000               1.0     42.350300    -71.081000
# 50%        2.170000               1.0     42.351900    -71.063100
# 75%        2.840000               1.0     42.364700    -71.054200
# max        7.860000               1.0     42.366100    -71.033000
#
#         temperature  ...  precipIntensityMax   uvIndexTime  temperatureMin  \
# count  55095.000000  ...        55095.000000  5.509500e+04    55095.000000
# mean      39.607343  ...            0.037436  1.544045e+09       33.476342
# std        6.732861  ...            0.055190  6.909305e+05        6.477382
# min       18.910000  ...            0.000000  1.543162e+09       15.630000
# 25%       36.500000  ...            0.000000  1.543421e+09       30.170000
# 50%       40.550000  ...            0.000400  1.543770e+09       34.240000
# 75%       43.610000  ...            0.091600  1.544807e+09       38.940000
# max       57.220000  ...            0.145900  1.545152e+09       43.100000
#
#        temperatureMinTime  temperatureMax  temperatureMaxTime  \
# count        5.509500e+04    55095.000000        5.509500e+04
# mean         1.544042e+09       45.277155        1.544048e+09
# std          6.900481e+05        5.652388        6.898592e+05
# min          1.543122e+09       33.510000        1.543154e+09
# 25%          1.543399e+09       42.570000        1.543439e+09
# 50%          1.543727e+09       44.680000        1.543788e+09
# 75%          1.544789e+09       46.910000        1.544814e+09
# max          1.545192e+09       57.870000        1.545109e+09
#
#        apparentTemperatureMin  apparentTemperatureMinTime  \
# count            55095.000000                5.509500e+04
# mean                29.753849                1.544049e+09
# std                  7.117307                6.870186e+05
# min                 11.810000                1.543136e+09
# 25%                 27.760000                1.543399e+09
# 50%                 30.130000                1.543745e+09
# 75%                 35.710000                1.544789e+09
# max                 40.050000                1.545134e+09
#
#        apparentTemperatureMax  apparentTemperatureMaxTime
# count            55095.000000                5.509500e+04
# mean                42.014321                1.544049e+09
# std                  6.951950                6.907825e+05
# min                 28.950000                1.543187e+09
# 25%                 36.570000                1.543439e+09
# 50%                 40.950000                1.543788e+09
# 75%                 44.120000                1.544818e+09
# max                 57.200000                1.545109e+09
#
# [8 rows x 46 columns]
#           timestamp           hour            day          month  \
# count  6.930710e+05  693071.000000  693071.000000  693071.000000
# mean   1.544046e+09      11.619137      17.794365      11.586684
# std    6.891925e+05       6.948114       9.982286       0.492429
# min    1.543204e+09       0.000000       1.000000      11.000000
# 25%    1.543444e+09       6.000000      13.000000      11.000000
# 50%    1.543737e+09      12.000000      17.000000      12.000000
# 75%    1.544828e+09      18.000000      28.000000      12.000000
# max    1.545161e+09      23.000000      30.000000      12.000000
#
#                price       distance  surge_multiplier       latitude  \
# count  637976.000000  693071.000000     693071.000000  693071.000000
# mean       16.545125       2.189430          1.013870      42.338172
# std         9.324359       1.138937          0.091641       0.047840
# min         2.500000       0.020000          1.000000      42.214800
# 25%         9.000000       1.280000          1.000000      42.350300
# 50%        13.500000       2.160000          1.000000      42.351900
# 75%        22.500000       2.920000          1.000000      42.364700
# max        97.500000       7.860000          3.000000      42.366100
#
#            longitude    temperature  ...  precipIntensityMax   uvIndexTime  \
# count  693071.000000  693071.000000  ...       693071.000000  6.930710e+05
# mean      -71.066151      39.584388  ...            0.037374  1.544044e+09
# std         0.020302       6.726084  ...            0.055214  6.912028e+05
# min       -71.105400      18.910000  ...            0.000000  1.543162e+09
# 25%       -71.081000      36.450000  ...            0.000000  1.543421e+09
# 50%       -71.063100      40.490000  ...            0.000400  1.543770e+09
# 75%       -71.054200      43.580000  ...            0.091600  1.544807e+09
# max       -71.033000      57.220000  ...            0.145900  1.545152e+09
#
#        temperatureMin  temperatureMinTime  temperatureMax  temperatureMaxTime  \
# count   693071.000000        6.930710e+05   693071.000000        6.930710e+05
# mean        33.457774        1.544042e+09       45.261313        1.544047e+09
# std          6.467224        6.901954e+05        5.645046        6.901353e+05
# min         15.630000        1.543122e+09       33.510000        1.543154e+09
# 25%         30.170000        1.543399e+09       42.570000        1.543439e+09
# 50%         34.240000        1.543727e+09       44.680000        1.543788e+09
# 75%         38.880000        1.544789e+09       46.910000        1.544814e+09
# max         43.100000        1.545192e+09       57.870000        1.545109e+09
#
#        apparentTemperatureMin  apparentTemperatureMinTime  \
# count           693071.000000                6.930710e+05
# mean                29.731002                1.544048e+09
# std                  7.110494                6.871862e+05
# min                 11.810000                1.543136e+09
# 25%                 27.760000                1.543399e+09
# 50%                 30.130000                1.543745e+09
# 75%                 35.710000                1.544789e+09
# max                 40.050000                1.545134e+09
#
#        apparentTemperatureMax  apparentTemperatureMaxTime
# count           693071.000000                6.930710e+05
# mean                41.997343                1.544048e+09
# std                  6.936841                6.910777e+05
# min                 28.950000                1.543187e+09
# 25%                 36.570000                1.543439e+09
# 50%                 40.950000                1.543788e+09
# 75%                 44.120000                1.544818e+09
# max                 57.200000                1.545109e+09
#
# [8 rows x 46 columns]

# %%
fig = plt.figure()
ax = na_price.hist(figsize=(24,24))
ax = df.hist(figsize=(24,24))
plt.show()

# %%
na_price.cab_type.value_counts().plot(kind='barh')

# %%
ax = na_price.name.value_counts().plot(kind='bar')
ax = df.name.value_counts().plot(kind='bar')
plt.show()

# %%
print(len(df[df.name == 'Taxi']))
print(len(df[df.price.isna()]))
# Out:
# 55095
# 55095

# %% [markdown]
# There are a total of ~55k instances where the value for price is NaN.
#
# With additional analysis, all rides with missing prices are for Uber Taxi rides. Additional information regarding [Uber Taxi](https://ride.guru/content/newsroom/what-is-uber-taxi):
#
# "UberTAXI is currently available in four cities within the US (Boston, Honolulu, New York City, and Washington, D.C.).
#
# How the Service Works:
# The Uber app allows users to request a ride via their Android or iPhone.  In the case of UberTAXI, the user will be given the option to hail licensed taxicabs only.  For the service, you will pay an additional $1-$2 booking fee.  Once a driver is signaled through the app, it usually takes less than 10 minutes for a car to arrive at your door.  During this brief wait period, Uber allows you to track the car's location so you know exactly when to expect its arrival.  The app will track the metered fare, an included 20% gratuity and will provide a cashless payment process by charging all Uber rides to an on file credit card attached to your account."
#
# It would appear that Uber Taxi uses a different system to calculate total price, as each field is blank. Without a way to calculate total fare, we will likely discard these datapoints.

# %%
# Create new dataframe to house Uber Taxi Data:
uber_taxi_df = df[df.name == 'Taxi']
#uber_taxi_df.head()

# Drop Uber Taxi Data from df:
no_taxi_df = df[df.name != 'Taxi']
print(len(df), len(no_taxi_df) + len(uber_taxi_df))
# Out:
# 693071 693071

# %% [markdown]
# Next, we'll preview the number of unique values in each column in the dataset. Based on this information, we may consider how best to categorize and engineer additional features for the data.

# %%
for col in no_taxi_df.columns:
    print(f'Unique vals: {col} - {len(no_taxi_df[col].unique())}')
# Out:
# Unique vals: id - 637976
# Unique vals: timestamp - 35796
# Unique vals: hour - 24
# Unique vals: day - 17
# Unique vals: month - 2
# Unique vals: datetime - 31350
# Unique vals: timezone - 1
# Unique vals: source - 12
# Unique vals: destination - 12
# Unique vals: cab_type - 2
# Unique vals: product_id - 12
# Unique vals: name - 12
# Unique vals: price - 147
# Unique vals: distance - 549
# Unique vals: surge_multiplier - 7
# Unique vals: latitude - 11
# Unique vals: longitude - 12
# Unique vals: temperature - 308
# Unique vals: apparentTemperature - 319
# Unique vals: short_summary - 9
# Unique vals: long_summary - 11
# Unique vals: precipIntensity - 63
# Unique vals: precipProbability - 29
# Unique vals: humidity - 51
# Unique vals: windSpeed - 291
# Unique vals: windGust - 286
# Unique vals: windGustTime - 25
# Unique vals: visibility - 227
# Unique vals: temperatureHigh - 129
# Unique vals: temperatureHighTime - 23
# Unique vals: temperatureLow - 133
# Unique vals: temperatureLowTime - 31
# Unique vals: apparentTemperatureHigh - 124
# Unique vals: apparentTemperatureHighTime - 27
# Unique vals: apparentTemperatureLow - 136
# Unique vals: apparentTemperatureLowTime - 32
# Unique vals: icon - 7
# Unique vals: dewPoint - 313
# Unique vals: pressure - 316
# Unique vals: windBearing - 195
# Unique vals: cloudCover - 83
# Unique vals: uvIndex - 3
# Unique vals: visibility.1 - 227
# Unique vals: ozone - 274
# Unique vals: sunriseTime - 110
# Unique vals: sunsetTime - 114
# Unique vals: moonPhase - 18
# Unique vals: precipIntensityMax - 65
# Unique vals: uvIndexTime - 20
# Unique vals: temperatureMin - 131
# Unique vals: temperatureMinTime - 25
# Unique vals: temperatureMax - 128
# Unique vals: temperatureMaxTime - 23
# Unique vals: apparentTemperatureMin - 137
# Unique vals: apparentTemperatureMinTime - 29
# Unique vals: apparentTemperatureMax - 125
# Unique vals: apparentTemperatureMaxTime - 27

# %% [markdown]
# With a better understanding of the number of unique values in each column, we'll next perform additional EDA for dataset features.

# %% [markdown]
# ## id

# %%
print(f'Num Unique IDs: {len(no_taxi_df.id.unique())}, Column lenth: {len(no_taxi_df.id)}')
# Out:
# Num Unique IDs: 637976, Column lenth: 637976

# %% [markdown]
# Since each transaction ID is a unique value, this column doesn't provide additional insight - we will drop it.

# %%
no_taxi_df = no_taxi_df.drop(['id'], axis=1)

# %% [markdown]
# ## timestamp, hour, day, month, datetime, timezone

# %%
time_df = no_taxi_df[['timestamp','hour', 'day', 'month', 'datetime', 'timezone']]
display(time_df.head(), time_df.describe())
# Out:
#       timestamp  hour  day  month             datetime          timezone
# 0  1.544953e+09     9   16     12  2018-12-16 09:30:07  America/New_York
# 1  1.543284e+09     2   27     11  2018-11-27 02:00:23  America/New_York
# 2  1.543367e+09     1   28     11  2018-11-28 01:00:22  America/New_York
# 3  1.543554e+09     4   30     11  2018-11-30 04:53:02  America/New_York
# 4  1.543463e+09     3   29     11  2018-11-29 03:49:20  America/New_York
#           timestamp           hour            day          month
# count  6.379760e+05  637976.000000  637976.000000  637976.000000
# mean   1.544046e+09      11.618528      17.797674      11.586550
# std    6.892028e+05       6.948776       9.982083       0.492452
# min    1.543204e+09       0.000000       1.000000      11.000000
# 25%    1.543444e+09       6.000000      13.000000      11.000000
# 50%    1.543737e+09      12.000000      17.000000      12.000000
# 75%    1.544828e+09      18.000000      28.000000      12.000000
# max    1.545161e+09      23.000000      30.000000      12.000000

# %%
df.month.value_counts().plot(kind='barh')

# %%
nov_df, dec_df = df[df.month == 11], df[df.month == 12]
display(nov_df.head(), dec_df.head())

#df = df[df['winner'] != 'draw']
# Out:
#                                      id     timestamp  hour  day  month  \
# 1  4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 2  981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
# 3  c2d88af2-d278-4bfd-a8d0-29ca77cc5512  1.543554e+09     4   30     11
# 4  e0126e1f-8ca9-4f2e-82b3-50505a09db9a  1.543463e+09     3   29     11
# 6  462816a3-820d-408b-8549-0b39e82f65ac  1.543209e+09     5   26     11
#
#               datetime          timezone            source  \
# 1  2018-11-27 02:00:23  America/New_York  Haymarket Square
# 2  2018-11-28 01:00:22  America/New_York  Haymarket Square
# 3  2018-11-30 04:53:02  America/New_York  Haymarket Square
# 4  2018-11-29 03:49:20  America/New_York  Haymarket Square
# 6  2018-11-26 05:03:00  America/New_York          Back Bay
#
#                destination cab_type  ... precipIntensityMax uvIndexTime  \
# 1            North Station     Lyft  ...             0.1300  1543251600
# 2            North Station     Lyft  ...             0.1064  1543338000
# 3            North Station     Lyft  ...             0.0000  1543507200
# 4            North Station     Lyft  ...             0.0001  1543420800
# 6  Northeastern University     Lyft  ...             0.1245  1543251600
#
#    temperatureMin  temperatureMinTime  temperatureMax  temperatureMaxTime  \
# 1           40.49          1543233600           47.30          1543251600
# 2           35.36          1543377600           47.55          1543320000
# 3           34.67          1543550400           45.03          1543510800
# 4           33.10          1543402800           42.18          1543420800
# 6           40.67          1543233600           46.46          1543255200
#
#    apparentTemperatureMin  apparentTemperatureMinTime  apparentTemperatureMax  \
# 1                   36.20                  1543291200                   43.92
# 2                   31.04                  1543377600                   44.12
# 3                   30.30                  1543550400                   38.53
# 4                   29.11                  1543392000                   35.75
# 6                   37.45                  1543291200                   43.81
#
#   apparentTemperatureMaxTime
# 1                 1543251600
# 2                 1543320000
# 3                 1543510800
# 4                 1543420800
# 6                 1543251600
#
# [5 rows x 57 columns]
#                                       id     timestamp  hour  day  month  \
# 0   424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 5   f6f6d7e4-3e18-4922-a5f5-181cdd3fa6f2  1.545071e+09    18   17     12
# 7   474d6376-bc59-4ec9-bf57-4e6d6faeb165  1.543780e+09    19    2     12
# 8   4f9fee41-fde3-4767-bbf1-a00e108701fb  1.543818e+09     6    3     12
# 13  23f145da-f0c1-4d1f-a184-496bc003a7db  1.544698e+09    10   13     12
#
#                datetime          timezone            source  \
# 0   2018-12-16 09:30:07  America/New_York  Haymarket Square
# 5   2018-12-17 18:25:12  America/New_York  Haymarket Square
# 7   2018-12-02 19:53:04  America/New_York          Back Bay
# 8   2018-12-03 06:28:02  America/New_York          Back Bay
# 13  2018-12-13 10:50:11  America/New_York         North End
#
#                 destination cab_type  ... precipIntensityMax uvIndexTime  \
# 0             North Station     Lyft  ...             0.1276  1544979600
# 5             North Station     Lyft  ...             0.0221  1545066000
# 7   Northeastern University     Lyft  ...             0.0916  1543770000
# 8   Northeastern University     Lyft  ...             0.0004  1543852800
# 13                 West End     Uber  ...             0.0001  1544716800
#
#     temperatureMin  temperatureMinTime  temperatureMax  temperatureMaxTime  \
# 0            39.89          1545012000           43.68          1544968800
# 5            34.19          1545048000           40.66          1545022800
# 7            36.32          1543726800           50.80          1543788000
# 8            43.09          1543896000           57.02          1543852800
# 13           18.29          1544688000           33.83          1544731200
#
#     apparentTemperatureMin  apparentTemperatureMinTime  \
# 0                    33.73                  1545012000
# 5                    27.39                  1545044400
# 7                    35.84                  1543748400
# 8                    39.90                  1543896000
# 13                   13.79                  1544688000
#
#     apparentTemperatureMax apparentTemperatureMaxTime
# 0                    38.07                 1544958000
# 5                    34.97                 1545080400
# 7                    50.13                 1543788000
# 8                    56.35                 1543852800
# 13                   32.85                 1544734800
#
# [5 rows x 57 columns]

# %%
print(f'Unique TS Values: {time_df.timestamp.nunique()}')
# Out:
# Unique TS Values: 35796

# %%
print(f'Unique DT Values: {time_df.datetime.nunique()}')
# Out:
# Unique DT Values: 31350

# %%
time_df.timezone.unique()
# Out:
# array(['America/New_York'], dtype=object)

# %% [markdown]
# Since all rides in the dataset ocur in the same timezone, we'll drop this column from the dataset.

# %%
no_taxi_df = no_taxi_df.drop(['timezone'], axis=1)

# %%
# CREATE A DAY OF WEEK COLUMN

# %%
'''plt.figure(figsize=(12,12))
df.timestamp.plot(kind='line')
plt.show()'''
# Out:
# "plt.figure(figsize=(12,12))\ndf.timestamp.plot(kind='line')\nplt.show()"

# %%
# Create Function to plot distribution of multiple columns
def plot_distribution(df, columns):
    """Takes a dataframe object (df=) and list of columns (columns=)
    and plots the distribution of each column in a 
    separate plot"""
    plt.figure()
    for col in df[columns]:
        df[col].hist()
        plt.title(col)
        plt.show();

# %% [markdown]
# ## source, destination

# %%
df.source.value_counts().plot(kind='barh')

# %%
df.source.value_counts()
sns.b ( df.source.value_counts())
# look at source vs lat/long to cluster
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-03a839f405fd> in <module>
#       1 df.source.value_counts()
# ----> 2 sns.b ( df.source.value_counts())
#       3 # look at source vs lat/long to cluster
#
# AttributeError: module 'seaborn' has no attribute 'b'

# %%
df.destination.value_counts().plot(kind='barh')

# %% [markdown]
# ## cab_type, product_id, name

# %%
for no_taxi_df[col] in (no_taxi_df.cab_type, no_taxi_df.product_id, no_taxi_df.name):
    print(f'{no_taxi_df[col].value_counts()}')
# Out:
# Uber    330568
# Lyft    307408
# Name: apparentTemperatureMaxTime, dtype: int64
# 9a0e7b09-b92b-4c41-9779-2ad22b4d779d    55096
# 6f72dfc5-27f1-42e8-84db-ccc7a75f6969    55096
# 6d318bcc-22a3-4af6-bddd-b409bfce1546    55096
# 6c84fd89-3f11-4782-9b50-97c468b19529    55095
# 55c66225-fbe7-4fd5-9072-eab1ece5e23e    55094
# 997acbb5-e102-41e1-b155-9df7de0a73f2    55091
# lyft_plus                               51235
# lyft_premier                            51235
# lyft_lux                                51235
# lyft_luxsuv                             51235
# lyft                                    51235
# lyft_line                               51233
# Name: apparentTemperatureMaxTime, dtype: int64
# UberXL          55096
# WAV             55096
# Black SUV       55096
# Black           55095
# UberX           55094
# UberPool        55091
# Lux             51235
# Lyft XL         51235
# Lux Black       51235
# Lyft            51235
# Lux Black XL    51235
# Shared          51233
# Name: apparentTemperatureMaxTime, dtype: int64

# %%
no_taxi_df.name.value_counts()
# Out:
# UberXL          55096
# WAV             55096
# Black SUV       55096
# Black           55095
# UberX           55094
# UberPool        55091
# Lux             51235
# Lyft XL         51235
# Lux Black       51235
# Lyft            51235
# Lux Black XL    51235
# Shared          51233
# Name: name, dtype: int64

# %% [markdown]
# Because product_id and name represent the same values, we'll drop the less descriptive 'product_id' column.

# %%
no_taxi_df = no_taxi_df.drop(['product_id'], axis=1)

# %% [markdown]
# ## price

# %%
no_taxi_df.price.hist()
no_taxi_df.price.describe()
# Out:
# count    637976.000000
# mean         16.545125
# std           9.324359
# min           2.500000
# 25%           9.000000
# 50%          13.500000
# 75%          22.500000
# max          97.500000
# Name: price, dtype: float64

# %% [markdown]
# ## distance

# %%
no_taxi_df.distance.hist()
no_taxi_df.distance.describe() # Safe to assume distances are measured in miles
# Out:
# count    637976.000000
# mean          2.189261
# std           1.135413
# min           0.020000
# 25%           1.270000
# 50%           2.160000
# 75%           2.930000
# max           7.860000
# Name: distance, dtype: float64

# %% [markdown]
# ## surge_multiplier

# %%
no_taxi_df.surge_multiplier.value_counts()
# Out:
# 1.00    617001
# 1.25     11085
# 1.50      5065
# 1.75      2420
# 2.00      2239
# 2.50       154
# 3.00        12
# Name: surge_multiplier, dtype: int64

# %%
no_taxi_df.surge_multiplier.hist()

# %% [markdown]
# ## latitude, longitude

# %%
no_taxi_df.latitude.value_counts(), no_taxi_df.longitude.value_counts # Use these to plot/overlay on map
# Out:
# (42.3519    103156
#  42.3647     90822
#  42.3661     87652
#  42.2148     81570
#  42.3503     56306
#  42.3505     50389
#  42.3644     39052
#  42.3429     38835
#  42.3588     38690
#  42.3398     27325
#  42.3559     24179
#  Name: latitude, dtype: int64,
#  <bound method IndexOpsMixin.value_counts of 0        -71.0330
#  1        -71.0330
#  2        -71.0330
#  3        -71.0330
#  4        -71.0330
#             ...
#  693065   -71.0643
#  693066   -71.0643
#  693067   -71.0643
#  693069   -71.0643
#  693070   -71.0643
#  Name: longitude, Length: 637976, dtype: float64>)

# %% [markdown]
# ## temperature, apparent temperature

# %%
no_taxi_df.temperature.describe()
# Out:
# count    637976.000000
# mean         39.582406
# std           6.725500
# min          18.910000
# 25%          36.450000
# 50%          40.490000
# 75%          43.580000
# max          57.220000
# Name: temperature, dtype: float64

# %%
fig = plt.figure(figsize=(10,10))

ax = df.temperature.hist(alpha=.5)
ax = df.apparentTemperature.hist(alpha=.5)
plt.show()

# %% [markdown]
# ## short_summary, long_summary

# %%
no_taxi_df.short_summary.value_counts().plot(kind='bar')

# %%
no_taxi_df.long_summary.value_counts().plot(kind='bar')

# %% [markdown]
# ## precipIntensity, precipProbability, humidity

# %%
no_taxi_df.precipIntensity.hist()

# %%
no_taxi_df.precipProbability.hist()

# %%
no_taxi_df.humidity.hist()

# %% [markdown]
# ## windSpeed, windGust, windGustTime, windBearing

# %%
plt.figure()
for col in no_taxi_df[['windSpeed', 'windGust', 'windGustTime']]:
    no_taxi_df[col].hist()
    plt.title(col)
    plt.show();

# %% [markdown]
# ## visibility

# %%
no_taxi_df.visibility.hist()

# %% [markdown]
# ## temperatureHigh, temperatureHighTime, temperatureLow, temperatureLowTime

# %%
plt.figure()
for col in no_taxi_df[['temperatureHigh', 'temperatureHighTime', 'temperatureLow', 'temperatureLowTime']]:
    no_taxi_df[col].hist()
    plt.title(col)
    plt.show();

# %%
test_cols = ['temperatureHigh', 'temperatureHighTime', 'temperatureLow', 'temperatureLowTime']

# %%
plot_distribution(df=no_taxi_df, columns=test_cols)

# %%
no_taxi_df.tem

# %% [markdown]
# ## apparentTemperatureHigh, apparentTemperatuerHighTime, apparentTemperatureLow, apparentTemperatureLowTime

# %%
apparent_temp_cols = ['apparentTemperatureHigh', \
                      'apparentTemperatureHighTime', \
                      'apparentTemperatureLow', \
                      'apparentTemperatureLowTime']

plot_distribution(df=no_taxi_df, columns=apparent_temp_cols)

# %% [markdown]
# ## temperatureMin, temperatureMinTime, temperatureMax, temperatureMaxTime

# %%
temp_min_max = ['temperatureMin', 'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime']
plot_distribution(df=no_taxi_df, columns=temp_min_max)

# %% [markdown]
# ## apparentTemperatureMin, apparentTemperatureMinTime, apparentTemperatureMax, apparentTemperatureMaxTime

# %%
apparent_temp_min_max = ['apparentTemperatureMin', 'apparentTemperatureMinTime', \
                         'apparentTemperatureMax', 'apparentTemperatureMaxTime']
plot_distribution(df=no_taxi_df, columns=apparent_temp_min_max)

# %% [markdown]
# ## icon

# %%
no_taxi_df.icon.value_counts().plot(kind='bar')

# %% [markdown]
# dewPoint

# %%
no_taxi_df.dewPoint.hist()

# %% [markdown]
# pressure

# %%
no_taxi_df.pressure.hist()

# %% [markdown]
# ## cloudCover

# %%
no_taxi_df.cloudCover.hist()

# %% [markdown]
# ## uvIndex, uvIndexTime

# %%
plot_distribution(df=no_taxi_df, columns=['uvIndex', 'uvIndexTime'])

# %% [markdown]
# ## visibility

# %%
no_taxi_df.visibility.hist()

# %% [markdown]
# ozone

# %%
no_taxi_df.ozone.hist()

# %% [markdown]
# sunriseTime, sunsetTime

# %%
plot_distribution(df=no_taxi_df, columns=['sunriseTime', 'sunsetTime'])

# %% [markdown]
# moonPhase

# %%
no_taxi_df.moonPhase.hist()

# %% [markdown]
# precipIntensityMax

# %%
no_taxi_df.precipIntensityMax.hist()

# %%
lyft_df = df[df['cab_type'] == 'Lyft']
uber_df = df[df['cab_type'] == 'Uber']

print(f'Uber:')
display(len(uber_df))
print(f'Lyft:')
display(len(lyft_df))

a = df.cab_type.value_counts().plot(kind='barh')

#sns.barplot(data=df, x=df.cab_type, y=df.cab_type.unique())
# Out:
# Uber:
# 385663
# Lyft:
# 307408

# %% [markdown]
# Next, we'll define a function that evaluates the multicollinearity of columns within a dataframe. As shown above, there are numerous columns that represent similar data, such as temperature and apparent temperature. Before modeling, any redundant features should be dropped or manipulated (feature engineering) to reduce redundancy.

# %%
def evaluate_mc(df, annot=False):
    """Produces correlation between columns
    of a dataframe."""
    # Evaluating multicollinearity:
    corr = df.corr()
    fig = plt.figure(figsize=(18,18))
    sol = (corr.where(np.triu(np.ones(corr.shape), k=1).astype(np.bool))
                     .stack()
                     .sort_values(ascending=False))
    ax = sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=annot, cmap='Blues', cbar=True)
    ax.set_title("Multicollinearity")

# %%
evaluate_mc(no_taxi_df)

# %%
evaluate_mc(df=)

# %%
print(no_taxi_df.corr().unstack().sort_values().drop_duplicates().nlargest(n=50))
# Out:
# timestamp                    timestamp                      1.000000
# sunsetTime                   sunriseTime                    1.000000
# uvIndexTime                  sunsetTime                     0.999997
# sunriseTime                  uvIndexTime                    0.999997
# temperatureHighTime          apparentTemperatureHighTime    0.999986
# temperatureLowTime           apparentTemperatureLowTime     0.999961
# temperatureHighTime          sunriseTime                    0.999920
#                              sunsetTime                     0.999920
# sunriseTime                  apparentTemperatureHighTime    0.999910
# apparentTemperatureHighTime  sunsetTime                     0.999910
# uvIndexTime                  temperatureHighTime            0.999909
# apparentTemperatureHighTime  uvIndexTime                    0.999895
# temperatureHighTime          temperatureMaxTime             0.999885
# temperatureMaxTime           apparentTemperatureHighTime    0.999870
# apparentTemperatureLowTime   sunsetTime                     0.999843
#                              sunriseTime                    0.999843
# uvIndexTime                  apparentTemperatureLowTime     0.999831
# sunsetTime                   temperatureLowTime             0.999822
# sunriseTime                  temperatureLowTime             0.999822
# uvIndexTime                  temperatureLowTime             0.999804
# temperatureMaxTime           sunriseTime                    0.999793
#                              sunsetTime                     0.999792
# uvIndexTime                  temperatureMaxTime             0.999780
# temperatureHighTime          apparentTemperatureLowTime     0.999716
# apparentTemperatureHighTime  apparentTemperatureLowTime     0.999710
# temperatureHighTime          temperatureLowTime             0.999695
# apparentTemperatureHighTime  temperatureLowTime             0.999684
# temperatureMaxTime           apparentTemperatureLowTime     0.999618
# temperatureLowTime           temperatureMaxTime             0.999522
# apparentTemperatureMinTime   temperatureMinTime             0.999376
# sunsetTime                   timestamp                      0.999372
# sunriseTime                  timestamp                      0.999372
# timestamp                    uvIndexTime                    0.999364
# uvIndexTime                  windGustTime                   0.999362
# sunsetTime                   windGustTime                   0.999357
# sunriseTime                  windGustTime                   0.999357
# timestamp                    temperatureHighTime            0.999332
# apparentTemperatureHighTime  timestamp                      0.999312
# windGustTime                 temperatureMaxTime             0.999302
# temperatureMaxTime           timestamp                      0.999290
# temperatureHighTime          windGustTime                   0.999252
# timestamp                    apparentTemperatureLowTime     0.999204
#                              temperatureLowTime             0.999175
# windGustTime                 apparentTemperatureHighTime    0.999163
# temperatureLowTime           temperatureMinTime             0.999147
# apparentTemperatureLowTime   apparentTemperatureMinTime     0.999083
# temperatureMinTime           apparentTemperatureLowTime     0.999054
# apparentTemperatureLowTime   windGustTime                   0.999034
# apparentTemperatureMinTime   temperatureLowTime             0.999023
# temperatureMinTime           uvIndexTime                    0.999016
# dtype: float64

# %%
print(no_taxi_df.corr().unstack().sort_values().drop_duplicates().nsmallest(n=50))
# Out:
# day                         month                         -0.861325
# windGustTime                moonPhase                     -0.854638
# moonPhase                   timestamp                     -0.846279
# apparentTemperatureMinTime  moonPhase                     -0.846008
# temperatureMaxTime          moonPhase                     -0.845285
# moonPhase                   apparentTemperatureLowTime    -0.845016
# uvIndexTime                 moonPhase                     -0.844854
# moonPhase                   sunsetTime                    -0.844735
#                             sunriseTime                   -0.844716
#                             temperatureLowTime            -0.844059
# temperatureHighTime         moonPhase                     -0.843450
# moonPhase                   apparentTemperatureHighTime   -0.843043
#                             temperatureMinTime            -0.841703
# precipProbability           visibility.1                  -0.761438
# humidity                    visibility.1                  -0.697860
# ozone                       apparentTemperatureHigh       -0.633244
# visibility                  precipIntensity               -0.600613
# apparentTemperatureLow      ozone                         -0.599911
# apparentTemperatureMax      ozone                         -0.591788
# dewPoint                    visibility                    -0.579974
# windSpeed                   pressure                      -0.574573
# windBearing                 precipIntensityMax            -0.554367
# visibility.1                precipIntensityMax            -0.544535
# longitude                   latitude                      -0.531443
# pressure                    moonPhase                     -0.528006
#                             windGust                      -0.513851
# ozone                       temperatureHigh               -0.489315
# temperatureLow              ozone                         -0.485325
# visibility                  cloudCover                    -0.477676
# precipProbability           windBearing                   -0.469847
# ozone                       apparentTemperature           -0.462401
# pressure                    temperatureMin                -0.454901
# month                       moonPhase                     -0.452655
# pressure                    ozone                         -0.451172
# day                         pressure                      -0.444738
#                             apparentTemperatureMax        -0.444366
# temperatureMax              ozone                         -0.443851
# precipIntensity             windBearing                   -0.433185
# ozone                       humidity                      -0.425874
#                             dewPoint                      -0.424844
# apparentTemperatureHigh     windGust                      -0.416502
# apparentTemperatureLow      temperatureMinTime            -0.416470
# temperatureLowTime          apparentTemperatureLow        -0.414898
# apparentTemperatureLowTime  apparentTemperatureLow        -0.411996
# apparentTemperatureMinTime  apparentTemperatureLow        -0.404343
# windGust                    apparentTemperatureLow        -0.403827
# apparentTemperatureLow      sunsetTime                    -0.403791
#                             sunriseTime                   -0.403759
# uvIndexTime                 apparentTemperatureLow        -0.403237
# timestamp                   apparentTemperatureLow        -0.402043
# dtype: float64

# %%
lat = pd.Series(data=df.latitude)
long = pd.Series(data=df.longitude)

df['gps'] = pd.concat(([lat, long]))
df.gps[0:10]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-629b34e61914> in <module>
#       2 long = pd.Series(data=df.longitude)
#       3
# ----> 4 df['gps'] = pd.concat(([lat, long]))
#       5 df.gps[0:10]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3470         else:
#    3471             # set column
# -> 3472             self._set_item(key, value)
#    3473
#    3474     def _setitem_slice(self, key, value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3547
#    3548         self._ensure_valid_index(value)
# -> 3549         value = self._sanitize_column(key, value)
#    3550         NDFrame._set_item(self, key, value)
#    3551
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3709
#    3710         if isinstance(value, Series):
# -> 3711             value = reindexer(value)
#    3712
#    3713         elif isinstance(value, DataFrame):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reindexer(value)
#    3700                     # duplicate axis
#    3701                     if not value.index.is_unique:
# -> 3702                         raise e
#    3703
#    3704                     # other
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reindexer(value)
#    3695                 # GH 4107
#    3696                 try:
# -> 3697                     value = value.reindex(self.index)._values
#    3698                 except Exception as e:
#    3699
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    4216     @Appender(generic.NDFrame.reindex.__doc__)
#    4217     def reindex(self, index=None, **kwargs):
# -> 4218         return super().reindex(index=index, **kwargs)
#    4219
#    4220     def drop(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4512         # perform the reindex on the axes
#    4513         return self._reindex_axes(
# -> 4514             axes, level, limit, tolerance, method, fill_value, copy
#    4515         ).__finalize__(self)
#    4516
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4533                 fill_value=fill_value,
#    4534                 copy=copy,
# -> 4535                 allow_dups=False,
#    4536             )
#    4537
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4575                 fill_value=fill_value,
#    4576                 allow_dups=allow_dups,
# -> 4577                 copy=copy,
#    4578             )
#    4579
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1249         # some axes don't allow reindexing with dups
#    1250         if not allow_dups:
# -> 1251             self.axes[axis]._can_reindex(indexer)
#    1252
#    1253         if axis >= self.ndim:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _can_reindex(self, indexer)
#    3360         # trying to reindex on an axis with duplicates
#    3361         if not self.is_unique and len(indexer):
# -> 3362             raise ValueError("cannot reindex from a duplicate axis")
#    3363
#    3364     def reindex(self, target, method=None, level=None, limit=None, tolerance=None):
#
# ValueError: cannot reindex from a duplicate axis

# %% [markdown]
# General things I want to investigate:
#
# target = num_rides, total_fare,

# %%
# Save X (feature) dataframes:

# Save y (target) dataframes:
